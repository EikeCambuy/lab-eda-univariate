# %%
##Part 01

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
df = pd.read_csv("amz_uk_price_prediction_dataset.csv")
df.head()
# Out:
#    uid        asin                                              title  stars  \
# 0    1  B09B96TG33  Echo Dot (5th generation, 2022 release) | Big ...    4.7
# 1    2  B01HTH3C8S  Anker Soundcore mini, Super-Portable Bluetooth...    4.7
# 2    3  B09B8YWXDF  Echo Dot (5th generation, 2022 release) | Big ...    4.7
# 3    4  B09B8T5VGV  Echo Dot with clock (5th generation, 2022 rele...    4.7
# 4    5  B09WX6QD65  Introducing Echo Pop | Full sound compact Wi-F...    4.6
#
#    reviews  price  isBestSeller  boughtInLastMonth        category
# 0    15308  21.99         False                  0  Hi-Fi Speakers
# 1    98099  23.99          True                  0  Hi-Fi Speakers
# 2    15308  21.99         False                  0  Hi-Fi Speakers
# 3     7205  31.99         False                  0  Hi-Fi Speakers
# 4     1881  17.99         False                  0  Hi-Fi Speakers

# %%
frequency_table = df['category'].value_counts()
frequency_table
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
#                                            ...
# Alexa Built-In Devices                       107
# Motorbike Chassis                            107
# Plugs                                        107
# Smart Home Security & Lighting               104
# Smart Speakers                                54
# Name: count, Length: 296, dtype: int64

# %%
top_5_df = df["category"].value_counts().head(5)
top_5_df
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
# Name: count, dtype: int64

# %%
##2.
sns.barplot(x= df["category"].index, y= df["category"].values, palette= "Set3");

# %%
sns.countplot(data = df, x= "category", palette="Set3");

# %%
sns.barplot(x=top_5_df.index, y=top_5_df.values, palette= "Set3");

# %%
top_5_df.value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette("Set3"))
# Out:
# <Axes: ylabel='count'>

# %%
##Part 02
mean_price = df["price"].mean()
median_price = df["price"].median()
mode_price = df["price"].mode()[0]

mean_price, median_price ,mode_price
# Out:
# (89.24380943923663, 19.09, 9.99)

# %%
mean_price = df["price"].mean()
mode_price = df["price"].mode()[0]

mean_price ,mode_price
# Out:
# (89.24380943923663, 9.99)

# %%
var_price = df["price"].var()
std_price = df["price"].std()
max_price = df["price"].max()
min_price = df["price"].min()
range_price = max_price - min_price
quantiles_price = df["price"].quantile([0.25, 0.5, 0.75])

var_price , std_price , range_price , quantiles_price
# Out:
# (119445.48532256528,
#  345.60886175352226,
#  100000.0,
#  0.25     9.99
#  0.50    19.09
#  0.75    45.99
#  Name: price, dtype: float64)

# %%
print(std_price)

q3 = np.percentile(df["price"],[75])
q1 = np.percentile(df["price"],[25])
percentile_price = q3 - q1
print (percentile_price)
# Out:
# 345.60886175352226
# [36.]

# %%
sns.histplot(df["price"], kde=True, bins=30, color="salmon")
plt.xlabel("Price")
plt.ylabel("Frebency")
plt.title("Product Price")
plt.show()

# %%
sns.histplot(top_5_df, kde=True, bins=30, color="salmon")
plt.xlabel("Price")
plt.ylabel("Frebency")
plt.title("Product Price top 5")
plt.show()

# %%
sns.boxplot(data = df['price'], color="lightblue")
# Out:
# <Axes: >

# %%
##Part 03.

mean_price_02 = df["stars"].mean()
median_price_02 = df["stars"].median()
mode_price_02 = df["stars"].mode()[0]

mean_price_02 , median_price_02 ,mode_price_02
# Out:
# (2.152836472966065, 0.0, 0.0)

# %%
var_price_2 = df["stars"].var()
std_price_2= df["stars"].std()
max_price_2= df["stars"].max()
min_price_2 = df["stars"].min()
range_price_2 = max_price - min_price
quantiles_price_2 = df["stars"].quantile([0.25, 0.5, 0.75])

var_price_2 , std_price_2 , range_price_2 , quantiles_price_2
# Out:
# (4.81743402976196,
#  2.1948653785054697,
#  100000.0,
#  0.25    0.0
#  0.50    0.0
#  0.75    4.4
#  Name: stars, dtype: float64)

# %%
## There is a unconscious rating

# %%
skewness_price = df["stars"].skew()
kurtosis_price = df["stars"].kurtosis()

skewness_price, kurtosis_price
# Out:
# (0.08120735761080985, -1.9260061280432985)

# %%
## The rating lean towards lowers lavues

# %%
sns.histplot(df["stars"], kde=True, bins=30, color="salmon")
plt.xlabel("Rating")
plt.ylabel("Frebency")
plt.title("Rating")
plt.show()
